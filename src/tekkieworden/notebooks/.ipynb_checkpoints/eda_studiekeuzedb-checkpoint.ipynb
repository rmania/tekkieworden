# %% [markdown]
# ### Demo Aanbod Techstudenten o.b.v Studiekeuze123 db + DUO HO inschrijfbestanden
#
# <img src="../../../docs/images/studiekeuze123_logo.png">
#
# **Work in Progress**!!!!

# %%
import numpy as np
import pandas as pd
import re
import matplotlib.pyplot as plt
import logging
logger = logging.getLogger()
logger.setLevel(logging.INFO)
import sys

sys.path.insert(0, "../")
sys.path.insert(0, "../db_config/")
sys.path.insert(0, "../helper_functions//")

from helper_functions.utilities import pandas_join_key_dual
from helper_functions.munge import (prepare_sdb_opleidingen_file, 
                                    prepare_duo_ho_files, 
                                    concat_unstack_duo_ho_files,
                                    clean_string_fields)

pd.set_option("display.max.columns", 100)
PATH_TO_RAW_DATA = '../../../data/raw/'

# %%
# inladen + prepareren Studiekeuze Excel (extract 17-04-2020)
# functie: munge/prepare_sdb_opleidingen_file
sdb = prepare_sdb_opleidingen_file(path=PATH_TO_RAW_DATA, file='studiekeuze123_all_20200417.xlsx')
# Out:
# INFO:root:dropping columns:
# ...

# %%
# dowloaden + prepareren DUO 03b-eerstejaars-ingeschrevenen-{hbo/wo}-domein-hbo-2019.csv
# functie: munge/prepare_duo_ho_files + concat_unstack_duo_ho_files
duo = concat_unstack_duo_ho_files(year = 2018)
# Out:
# INFO:root:hbo_inscriptions_2019.csv shape: (3822, 18)
# INFO:root:wo_inscriptions_2019.csv shape: (3231, 18)
# INFO:root:Concatting ('hbo_inscriptions_2019.csv', 'wo_inscriptions_2019.csv')
# . Duo file shape: (7053, 18)
# INFO:root:summing MAN, VROUW into TOTAL
# INFO:root:Merge back the concatted gemeentes
# INFO:root:Duo file shape: (2496, 10)
# INFO:root:Extract
# :   brinnummer_duo                     instellingsnaam_duo  \
# 0           00DV  Protestantse Theologische Universiteit
# 1           00DV  Protestantse Theologische Universiteit
# 2           00DV  Protestantse Theologische Universiteit
# 3           00DV  Protestantse Theologische Universiteit
# 4           00IC                  Katholieke PABO Zwolle
#
#                     opleidingsnaam_duo  croho_onderdeel  \
# 0                    Gemeentepredikant  taal en cultuur
# 1                       Predikantschap  taal en cultuur
# 2             Theologie (joint degree)  taal en cultuur
# ...

# %% [markdown]
# ### Merge beide bestanden

# %%
sdb_join_cols = ['brinnummer_sdb', 'naamopleiding_sdb', 'soortopleiding_sdb']
sdb_add_cols = ['cluster_sdb', 'sector_sdb', 
                'kortebeschrijvingopleiding_sdb',
                'eerstejaarsaantal_sdb', 'studentenaantal_sdb']

df = pandas_join_key_dual(left_df=duo, right_df=sdb[sdb_join_cols + sdb_add_cols], 
                     left_key=['brinnummer_duo', 'opleidingsnaam_duo', 'soortopleiding_duo'], 
                     right_key=sdb_join_cols, how='inner')
df = df.drop(sdb_join_cols, axis=1)

# nlp preprocessing op kortebeschrijvingopleiding_sdb kolom
df['kortebeschrijvingopleiding_sdb'] = \ 
df['kortebeschrijvingopleiding_sdb'].fillna('geen beschrijving').apply(clean_string_fields)

# %%
df.head(1)
# Out:
#   brinnummer_duo                     instellingsnaam_duo opleidingsnaam_duo  \
# 0           00DV  Protestantse Theologische Universiteit  Gemeentepredikant
#
#    croho_onderdeel        croho_subonderdeel soortopleiding_duo   man  vrouw  \
# 0  taal en cultuur  n.v.t. (taal en cultuur)             master  10.0    3.0
#
#    tot_2018_duo gemeentenummer_duo                     cluster_sdb  \
# 0          13.0          [14, 363]  Theologie en Levensbeschouwing
#
#          sector_sdb                     kortebeschrijvingopleiding_sdb  \
# 0  Kunst en Cultuur  predikant kerk slag zie jij jezelf pionieren g...
#
#    eerstejaarsaantal_sdb  studentenaantal_sdb
# 0                   18.0                103.0

# %% [markdown]
# Nu kunst om de techopleidingen er uit te filteren
#
# - filteren op `cluster_sdb`
# - filteren op basis van een set aan steekwoorden op `opleidingsnaam_duo`, `kortebeschrijvingopleiding_sdb`

# %%
df.opleidingsnaam_duo.value_counts().keys().tolist()
# Out:
# ['Opleiding tot leraar Basisonderwijs',
#  'Social Work',
#  'Human Resource Management',
#  'Finance & Control',
#  'Accountancy',
#  'Bedrijfskunde',
#  'Technische Bedrijfskunde',
#  'Opleiding tot Verpleegkundige',
#  'Pedagogiek',
#  'Filosofie',
#  'Werktuigbouwkunde',
#  'International Business',
#  'Ondernemerschap & Retail Management',
#  'Communicatie',
#  'HBO-ICT',
#  'Geneeskunde',
#  'Informatica',
#  'Bouwkunde',
#  'Elektrotechniek',
#  'HBO - Rechten',
#  'Theologie',
#  'Sociologie',
#  'Chemie',
#  'Muziek',
#  'Rechtsgeleerdheid',
#  'Geschiedenis',
#  'Fiscaal Recht',
#  'Civiele Techniek',
#  'Biologie en Medisch Laboratoriumonderzoek',
#  'Psychologie',
#  'Management in de Zorg',
#  'Tourism Management',
#  'Pedagogisch Educatief Professional',
#  'Communication and Multimedia Design',
#  'Opleiding tot Fysiotherapeut',
#  'Facility Management',
#  'Pedagogische Wetenschappen',
#  'Docent Muziek',
#  'Educational Needs',
#  'Advanced Nursing Practice',
# ...

# %%
# mogelijke keywords op techstudies te filteren
keywords = ['data', 'Intelligence', 'Data Science', 'Kunstmatige Intelligentie', 'computer science',
            'analytic', 'analist', 'artificial', 'statistic',
            'developer', 'online',  'design', 'media', 'multimedia', 'online', 'marketing', 'e-commerce',
            'grafisch', 'web', 'software', 'hardware', 'ontwikkelaar', 'content',
            'creative', 'digital', 'ontwerp',
            'information', 'ict', 'cyber', 'hack' ,'engineer', 'informatica', 'systeem', 'beheerder'
            'Technische', 'wiskunde', 'Mathematics', 'applied', 'quantitative',
            'computer', 'Technology']

# %%
cols_to_check = ['opleidingsnaam_duo', 'croho_onderdeel', 'cluster_sdb']
for c in cols_to_check:
    tech = df[df[c].str.contains("|".join(keywords), flags=re.IGNORECASE)]

# %% [markdown]
# ### voorbeeld plot. (no worries dit maken we mooi als we allemaal achter de cijfers staan ;-)

# %%
f = {'tot_2018_duo': 'sum'} #, 'eerstejaarsaantal_sdb' : 'sum','studentenaantal_sdb':'sum'}
q = (tech.groupby(['opleidingsnaam_duo', 'soortopleiding_duo']).agg(f)
.unstack('soortopleiding_duo')
)
idx = pd.IndexSlice
q['tot'] = q.loc[:, idx[:, ('associate degree', 'bachelor', 'master')]].sum(axis=1)

# %%
f, ax = plt.subplots(figsize=(8,10))
q['tot'].sort_values(ascending=False)[:25].plot(kind='barh', ax=ax)
ax.invert_yaxis()
